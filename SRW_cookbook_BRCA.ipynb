# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import SRW_v044 as SRW
import pickle

# %%
edges, features, node_names = SRW.load_network('data/BRCA_edge2features_2.txt')
# Out:
# * Loading network...

# %%
P_init_train, sample_names_train = SRW.load_samples('data/BRCA_training_data_2.txt', node_names)
# Out:
# 	- Nodes in adjacency matrix: 557

# %%
P_init_val, sample_names_val = SRW.load_samples('data/BRCA_validation_data_2.txt', node_names)
# Out:
# 	- Nodes in adjacency matrix: 557

# %%
group_labels_train = SRW.load_grouplabels('data/BRCA_training_lables_2.txt')

# %%
group_labels_val = SRW.load_grouplabels('data/BRCA_validation_lables_2.txt')

# %%
nnodes = len(node_names)
rst_prob = 0.3
lam = 1e-1

# %%
feature_names = []
with open('data/BRCA_feature_names_2.txt') as f:
    for line in f.read().rstrip().splitlines():
        feature_names.append(line)
feature_names.append('selfloop')
feature_names.append('intercept')

# %%
import SRW_v044 as SRW

SRW_obj = SRW.SRW_solver(edges, features, nnodes, P_init_train, rst_prob, group_labels_train, lam, 
                         w_init_sd=0.01, w=None, feature_names=feature_names, 
                         sample_names=sample_names_train, node_names=node_names, loss='WMW', 
                         norm_type='L1', learning_rate=0.2, update_w_func='Adam', 
                         P_init_val=P_init_val, group_labels_val=group_labels_val, ncpus=16, 
                         maxit=1000, early_stop=500, WMW_b=2e-4)

# %% [markdown]
# ### Arguments of SRW_solver objects
# **edges** (e by 2, int, ndarray): Edges in the network
# **features** (e by w, float, csc_matrix): Edge features
# **nnodes** (int): Number of nodes in the network
# **P_init** (m by n, float, csr_matrix): Initial state of samples (training set)
# **rst_prob** (float): Reset probability of Random Walk
# **group_labels** (m by 1, str/int, list): Group labels of samples (training set)
# **lam** (float): Regularization parameter, controling the amount of L1/L2 norm
# **w_init_sd** (float): Standard deviation for weight initialization (default 0.01)
# **w** (w by 1, float, list): Initial weights (default None)
# **feature_names** (w by 1, str, list): Feature names (default [])
# **sample_names** (m by 1, str, list): Feature names (default [])
# **node_names** (n by 1, str, list): Feature names (default [])
# **loss** {'WMW'}: Type of the loss funtion (default 'WMW')
# **norm_type** {'L1', 'L2'}: Type of the norm (derault 'L1')
# **learning_rate** (float): Learning rate (default 0.1)
# **update_w_func** {'momentum', 'Nesterov', 'Adam', 'Nadam'}: Function for updating parameters (default 'Adam')
# **P_init_val** (m by n, float, csr_matrix): Initial state of samples (validation set) (default None)
# **group_labels_val** (m by 1, str/int, list): Group labels of samples (validation set) (default None)
# **ncpus** (int): Number of CPUs to use for multiprocess.Pool (default: -1, use all cpus)
# **maxit** (int): Max number of iterations for training the model (default: 1000)
# **early_stop** (int): Stop the learning if the performance doesn't improve in x iterations (default: None)
# **WMW_b** (float): Parameter b in the WMW loss function (default: 2e-4)

# %%
SRW_obj.train_SRW_GD()
# Out:
# finished calculating strength_grad: 22:51:41
# finished network propagation: 22:51:48
# finished calculating P_grad using pool: 22:52:07
# finished calculating J and J_grad: 22:52:15
# *** 0 iteration: J is 260.3156660666981 cost_val is 127.97349236991225
# *** accuracy is 0.5580589254766031 accuracy_val is 0.5314685314685315
#
#
# finished calculating strength_grad: 22:52:16
# finished network propagation: 22:52:17
# finished calculating P_grad using pool: 22:52:36
# finished calculating J and J_grad: 22:52:39
# *** 1 iteration: J is 260.0714324881586 cost_val is 127.08670265499002
# *** accuracy is 0.5545927209705372 accuracy_val is 0.5524475524475524
#
#
# finished calculating strength_grad: 22:52:39
# finished network propagation: 22:52:40
# finished calculating P_grad using pool: 22:53:00
# finished calculating J and J_grad: 22:53:03
# *** 2 iteration: J is 259.02810642710335 cost_val is 126.78980537249502
# *** accuracy is 0.5563258232235702 accuracy_val is 0.5629370629370629
#
#
# finished calculating strength_grad: 22:53:03
# finished network propagation: 22:53:04
# finished calculating P_grad using pool: 22:53:27
# finished calculating J and J_grad: 22:53:30
# *** 3 iteration: J is 257.5548826858344 cost_val is 126.6230874562126
# *** accuracy is 0.5632582322357019 accuracy_val is 0.5699300699300699
#
#
# finished calculating strength_grad: 22:53:31
# finished network propagation: 22:53:31
# finished calculating P_grad using pool: 22:53:57
# finished calculating J and J_grad: 22:53:59
# *** 4 iteration: J is 254.95688089460145 cost_val is 126.12261889644819
# *** accuracy is 0.5771230502599654 accuracy_val is 0.5664335664335665
#
#
# finished calculating strength_grad: 22:53:59
# finished network propagation: 22:54:00
# finished calculating P_grad using pool: 22:54:27
# finished calculating J and J_grad: 22:54:29
# *** 5 iteration: J is 253.20850483529327 cost_val is 124.62819359829409
# *** accuracy is 0.5753899480069324 accuracy_val is 0.5629370629370629
#
#
# finished calculating strength_grad: 22:54:30
# finished network propagation: 22:54:30
# finished calculating P_grad using pool: 22:54:57
# finished calculating J and J_grad: 22:55:00
# *** 6 iteration: J is 255.21105384317548 cost_val is 124.07615243359538
# *** accuracy is 0.5580589254766031 accuracy_val is 0.5559440559440559
#
#
# finished calculating strength_grad: 22:55:00
# finished network propagation: 22:55:01
# finished calculating P_grad using pool: 22:55:26
# finished calculating J and J_grad: 22:55:28
# *** 7 iteration: J is 251.5681235163526 cost_val is 125.16761534046641
# *** accuracy is 0.5736568457538995 accuracy_val is 0.5594405594405595
#
#
# finished calculating strength_grad: 22:55:28
# finished network propagation: 22:55:28
# finished calculating P_grad using pool: 22:55:54
# finished calculating J and J_grad: 22:55:56
# *** 8 iteration: J is 250.51011197796683 cost_val is 126.2884494783511
# *** accuracy is 0.5771230502599654 accuracy_val is 0.5664335664335665
#
#
# finished calculating strength_grad: 22:55:56
# finished network propagation: 22:55:57
# finished calculating P_grad using pool: 22:56:21
# finished calculating J and J_grad: 22:56:23
# *** 9 iteration: J is 250.40201586640313 cost_val is 126.22372618359005
# *** accuracy is 0.5788561525129983 accuracy_val is 0.5664335664335665
#
#
# finished calculating strength_grad: 22:56:23
# finished network propagation: 22:56:23
# finished calculating P_grad using pool: 22:56:48
# finished calculating J and J_grad: 22:56:50
# *** 10 iteration: J is 248.6622338184918 cost_val is 125.33072499527768
# *** accuracy is 0.5805892547660312 accuracy_val is 0.5664335664335665
#
#
# finished calculating strength_grad: 22:56:50
# finished network propagation: 22:56:50
# finished calculating P_grad using pool: 22:57:15
# finished calculating J and J_grad: 22:57:17
# *** 11 iteration: J is 246.0468884514019 cost_val is 123.82875275249549
# *** accuracy is 0.587521663778163 accuracy_val is 0.5559440559440559
#
#
# finished calculating strength_grad: 22:57:17
# finished network propagation: 22:57:17
# finished calculating P_grad using pool: 22:57:43
# finished calculating J and J_grad: 22:57:44
# *** 12 iteration: J is 243.6477780713538 cost_val is 122.32381672262663
# *** accuracy is 0.5979202772963604 accuracy_val is 0.5664335664335665
#
#
# finished calculating strength_grad: 22:57:44
# finished network propagation: 22:57:45
# finished calculating P_grad using pool: 22:58:10
# finished calculating J and J_grad: 22:58:12
# *** 13 iteration: J is 243.22787269548385 cost_val is 120.67445802852244
# *** accuracy is 0.5944540727902946 accuracy_val is 0.5734265734265734
#
#
# finished calculating strength_grad: 22:58:12
# finished network propagation: 22:58:12
# finished calculating P_grad using pool: 22:58:38
# finished calculating J and J_grad: 22:58:39
# *** 14 iteration: J is 240.42194627610795 cost_val is 119.59897255492311
# *** accuracy is 0.5996533795493935 accuracy_val is 0.583916083916084
#
#
# finished calculating strength_grad: 22:58:39
# finished network propagation: 22:58:40
# finished calculating P_grad using pool: 22:59:06
# finished calculating J and J_grad: 22:59:07
# *** 15 iteration: J is 237.26401492251676 cost_val is 119.81859620548242
# *** accuracy is 0.608318890814558 accuracy_val is 0.5699300699300699
#
#
# finished calculating strength_grad: 22:59:07
# finished network propagation: 22:59:08
# finished calculating P_grad using pool: 22:59:33
# finished calculating J and J_grad: 22:59:35
# *** 16 iteration: J is 237.1205268181397 cost_val is 118.99006637448934
# *** accuracy is 0.610051993067591 accuracy_val is 0.5769230769230769
#
#
# finished calculating strength_grad: 22:59:35
# finished network propagation: 22:59:35
# finished calculating P_grad using pool: 23:00:01
# finished calculating J and J_grad: 23:00:03
# *** 17 iteration: J is 236.06068527343456 cost_val is 117.8372427954536
# *** accuracy is 0.6117850953206239 accuracy_val is 0.5769230769230769
#
#
# finished calculating strength_grad: 23:00:03
# finished network propagation: 23:00:03
# finished calculating P_grad using pool: 23:00:29
# finished calculating J and J_grad: 23:00:31
# *** 18 iteration: J is 236.23633381589278 cost_val is 117.59481314674615
# *** accuracy is 0.6065857885615251 accuracy_val is 0.5734265734265734
#
#
# finished calculating strength_grad: 23:00:31
# finished network propagation: 23:00:31
# finished calculating P_grad using pool: 23:00:57
# finished calculating J and J_grad: 23:00:58
# *** 19 iteration: J is 234.9873830774048 cost_val is 117.842387043847
# *** accuracy is 0.6135181975736569 accuracy_val is 0.5804195804195804
#
#
# finished calculating strength_grad: 23:00:59
# finished network propagation: 23:00:59
# finished calculating P_grad using pool: 23:01:25
# finished calculating J and J_grad: 23:01:27
# *** 20 iteration: J is 233.0143116101024 cost_val is 117.86631285497009
# *** accuracy is 0.6204506065857885 accuracy_val is 0.5874125874125874
#
#
# finished calculating strength_grad: 23:01:27
# finished network propagation: 23:01:27
# finished calculating P_grad using pool: 23:01:53
# finished calculating J and J_grad: 23:01:55
# *** 21 iteration: J is 232.49454620969775 cost_val is 116.87373426439657
# *** accuracy is 0.6187175043327556 accuracy_val is 0.583916083916084
#
#
# finished calculating strength_grad: 23:01:55
# finished network propagation: 23:01:55
# finished calculating P_grad using pool: 23:02:22
# finished calculating J and J_grad: 23:02:23
# *** 22 iteration: J is 231.37624930689591 cost_val is 115.37484485795424
# *** accuracy is 0.6152512998266898 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 23:02:23
# finished network propagation: 23:02:24
# finished calculating P_grad using pool: 23:02:50
# finished calculating J and J_grad: 23:02:52
# *** 23 iteration: J is 230.60974660759842 cost_val is 113.87321511175763
# *** accuracy is 0.6187175043327556 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 23:02:52
# finished network propagation: 23:02:52
# finished calculating P_grad using pool: 23:03:19
# finished calculating J and J_grad: 23:03:21
# *** 24 iteration: J is 230.1747377164899 cost_val is 112.25363369132265
# *** accuracy is 0.6135181975736569 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 23:03:21
# finished network propagation: 23:03:22
# finished calculating P_grad using pool: 23:03:49
# finished calculating J and J_grad: 23:03:50
# *** 25 iteration: J is 229.48609578611286 cost_val is 110.58097257720692
# *** accuracy is 0.6169844020797227 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:03:51
# finished network propagation: 23:03:51
# finished calculating P_grad using pool: 23:04:18
# finished calculating J and J_grad: 23:04:20
# *** 26 iteration: J is 228.6778194458792 cost_val is 109.30042317676411
# *** accuracy is 0.6273830155979203 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 23:04:20
# finished network propagation: 23:04:21
# finished calculating P_grad using pool: 23:04:48
# finished calculating J and J_grad: 23:04:49
# *** 27 iteration: J is 227.54689663377445 cost_val is 108.99309363901345
# *** accuracy is 0.6256499133448874 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:04:49
# finished network propagation: 23:04:50
# finished calculating P_grad using pool: 23:05:17
# finished calculating J and J_grad: 23:05:19
# *** 28 iteration: J is 226.37227253172034 cost_val is 109.38229561786183
# *** accuracy is 0.6377816291161178 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:05:19
# finished network propagation: 23:05:19
# finished calculating P_grad using pool: 23:05:46
# finished calculating J and J_grad: 23:05:48
# *** 29 iteration: J is 225.32308720450501 cost_val is 108.97173679764234
# *** accuracy is 0.6360485268630849 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:05:48
# finished network propagation: 23:05:49
# finished calculating P_grad using pool: 23:06:16
# finished calculating J and J_grad: 23:06:18
# *** 30 iteration: J is 224.1348071047415 cost_val is 107.6482814343928
# *** accuracy is 0.6377816291161178 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:06:18
# finished network propagation: 23:06:18
# finished calculating P_grad using pool: 23:06:47
# finished calculating J and J_grad: 23:06:49
# *** 31 iteration: J is 223.81410895313087 cost_val is 105.85215309301722
# *** accuracy is 0.634315424610052 accuracy_val is 0.6398601398601399
#
#
# finished calculating strength_grad: 23:06:49
# finished network propagation: 23:06:49
# finished calculating P_grad using pool: 23:07:18
# finished calculating J and J_grad: 23:07:20
# *** 32 iteration: J is 223.49122502727516 cost_val is 105.43278477410713
# *** accuracy is 0.6360485268630849 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:07:20
# finished network propagation: 23:07:21
# finished calculating P_grad using pool: 23:07:49
# finished calculating J and J_grad: 23:07:50
# *** 33 iteration: J is 223.66192503331953 cost_val is 106.0784862690185
# *** accuracy is 0.6360485268630849 accuracy_val is 0.6363636363636364
#
#
# finished calculating strength_grad: 23:07:50
# finished network propagation: 23:07:51
# finished calculating P_grad using pool: 23:08:20
# finished calculating J and J_grad: 23:08:21
# *** 34 iteration: J is 223.42709378308024 cost_val is 104.94501035916149
# *** accuracy is 0.6308492201039861 accuracy_val is 0.6363636363636364
#
#
# finished calculating strength_grad: 23:08:22
# finished network propagation: 23:08:22
# finished calculating P_grad using pool: 23:08:51
# finished calculating J and J_grad: 23:08:52
# *** 35 iteration: J is 222.58394947740473 cost_val is 103.85241570622254
# *** accuracy is 0.6377816291161178 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:08:53
# finished network propagation: 23:08:53
# finished calculating P_grad using pool: 23:09:22
# finished calculating J and J_grad: 23:09:23
# *** 36 iteration: J is 221.65572676389783 cost_val is 103.76786254771788
# *** accuracy is 0.6395147313691508 accuracy_val is 0.6398601398601399
#
#
# finished calculating strength_grad: 23:09:24
# finished network propagation: 23:09:24
# finished calculating P_grad using pool: 23:09:52
# finished calculating J and J_grad: 23:09:54
# *** 37 iteration: J is 221.39400417927496 cost_val is 103.8043556827145
# *** accuracy is 0.6377816291161178 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:09:54
# finished network propagation: 23:09:54
# finished calculating P_grad using pool: 23:10:22
# finished calculating J and J_grad: 23:10:24
# *** 38 iteration: J is 220.60133534763315 cost_val is 104.06144953412698
# *** accuracy is 0.6447140381282496 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:10:24
# finished network propagation: 23:10:24
# finished calculating P_grad using pool: 23:10:53
# finished calculating J and J_grad: 23:10:54
# *** 39 iteration: J is 220.32564504088793 cost_val is 103.63279634590617
# *** accuracy is 0.6447140381282496 accuracy_val is 0.6503496503496503
#
#
# finished calculating strength_grad: 23:10:54
# finished network propagation: 23:10:55
# finished calculating P_grad using pool: 23:11:23
# finished calculating J and J_grad: 23:11:24
# *** 40 iteration: J is 219.8659295212711 cost_val is 102.85826658777077
# *** accuracy is 0.6429809358752167 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:11:25
# finished network propagation: 23:11:25
# finished calculating P_grad using pool: 23:11:53
# finished calculating J and J_grad: 23:11:55
# *** 41 iteration: J is 219.64986155827017 cost_val is 102.75669248343539
# *** accuracy is 0.6464471403812825 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:11:55
# finished network propagation: 23:11:55
# finished calculating P_grad using pool: 23:12:23
# finished calculating J and J_grad: 23:12:25
# *** 42 iteration: J is 219.30274429281283 cost_val is 103.51379959516146
# *** accuracy is 0.6481802426343154 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:12:25
# finished network propagation: 23:12:25
# finished calculating P_grad using pool: 23:12:54
# finished calculating J and J_grad: 23:12:55
# *** 43 iteration: J is 218.39152392016294 cost_val is 102.93741529092705
# *** accuracy is 0.6499133448873483 accuracy_val is 0.6503496503496503
#
#
# finished calculating strength_grad: 23:12:55
# finished network propagation: 23:12:56
# finished calculating P_grad using pool: 23:13:25
# finished calculating J and J_grad: 23:13:26
# *** 44 iteration: J is 217.9362010338422 cost_val is 102.62843037788859
# *** accuracy is 0.6533795493934142 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:13:26
# finished network propagation: 23:13:27
# finished calculating P_grad using pool: 23:13:55
# finished calculating J and J_grad: 23:13:57
# *** 45 iteration: J is 217.1501980129495 cost_val is 102.7618448137709
# *** accuracy is 0.6516464471403813 accuracy_val is 0.6503496503496503
#
#
# finished calculating strength_grad: 23:13:57
# finished network propagation: 23:13:57
# finished calculating P_grad using pool: 23:14:26
# finished calculating J and J_grad: 23:14:27
# *** 46 iteration: J is 215.8996304778904 cost_val is 102.17574885888664
# *** accuracy is 0.6568457538994801 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:14:28
# finished network propagation: 23:14:28
# finished calculating P_grad using pool: 23:14:57
# finished calculating J and J_grad: 23:14:58
# *** 47 iteration: J is 214.955359274379 cost_val is 102.2554552671155
# *** accuracy is 0.658578856152513 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:14:59
# finished network propagation: 23:14:59
# finished calculating P_grad using pool: 23:15:28
# finished calculating J and J_grad: 23:15:29
# *** 48 iteration: J is 214.67049076800745 cost_val is 102.5204678213165
# *** accuracy is 0.6568457538994801 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:15:30
# finished network propagation: 23:15:30
# finished calculating P_grad using pool: 23:15:59
# finished calculating J and J_grad: 23:16:00
# *** 49 iteration: J is 214.08623597161426 cost_val is 102.71044579617758
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:16:01
# finished network propagation: 23:16:01
# finished calculating P_grad using pool: 23:16:30
# finished calculating J and J_grad: 23:16:32
# *** 50 iteration: J is 214.12144999121705 cost_val is 102.85178796021425
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:16:32
# finished network propagation: 23:16:32
# finished calculating P_grad using pool: 23:17:01
# finished calculating J and J_grad: 23:17:03
# *** 51 iteration: J is 213.66933060910134 cost_val is 103.109013357673
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6468531468531469
#
#
# finished calculating strength_grad: 23:17:03
# finished network propagation: 23:17:03
# finished calculating P_grad using pool: 23:17:33
# finished calculating J and J_grad: 23:17:34
# *** 52 iteration: J is 213.46154773952912 cost_val is 103.41424088183082
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:17:35
# finished network propagation: 23:17:35
# finished calculating P_grad using pool: 23:18:04
# finished calculating J and J_grad: 23:18:06
# *** 53 iteration: J is 213.9313886185214 cost_val is 102.79817774669563
# *** accuracy is 0.6551126516464472 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:18:06
# finished network propagation: 23:18:07
# finished calculating P_grad using pool: 23:18:36
# finished calculating J and J_grad: 23:18:38
# *** 54 iteration: J is 213.04476477005264 cost_val is 103.64947449309179
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6398601398601399
#
#
# finished calculating strength_grad: 23:18:38
# finished network propagation: 23:18:39
# finished calculating P_grad using pool: 23:19:08
# finished calculating J and J_grad: 23:19:10
# *** 55 iteration: J is 212.31985179521624 cost_val is 103.55041135794579
# *** accuracy is 0.658578856152513 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:19:10
# finished network propagation: 23:19:10
# finished calculating P_grad using pool: 23:19:40
# finished calculating J and J_grad: 23:19:41
# *** 56 iteration: J is 211.8809485653017 cost_val is 103.93041780887565
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6433566433566433
#
#
# finished calculating strength_grad: 23:19:42
# finished network propagation: 23:19:42
# finished calculating P_grad using pool: 23:20:12
# finished calculating J and J_grad: 23:20:13
# *** 57 iteration: J is 211.40921447370513 cost_val is 104.86249361368745
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6363636363636364
#
#
# finished calculating strength_grad: 23:20:14
# finished network propagation: 23:20:14
# finished calculating P_grad using pool: 23:20:44
# finished calculating J and J_grad: 23:20:45
# *** 58 iteration: J is 211.72919398906112 cost_val is 104.91268186483222
# *** accuracy is 0.6655112651646448 accuracy_val is 0.6363636363636364
#
#
# finished calculating strength_grad: 23:20:45
# finished network propagation: 23:20:46
# finished calculating P_grad using pool: 23:21:16
# finished calculating J and J_grad: 23:21:17
# *** 59 iteration: J is 211.54005819795893 cost_val is 106.97418694984209
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:21:17
# finished network propagation: 23:21:18
# finished calculating P_grad using pool: 23:21:48
# finished calculating J and J_grad: 23:21:49
# *** 60 iteration: J is 210.85076485660176 cost_val is 106.4981947434498
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:21:50
# finished network propagation: 23:21:50
# finished calculating P_grad using pool: 23:22:20
# finished calculating J and J_grad: 23:22:22
# *** 61 iteration: J is 211.44784481213065 cost_val is 106.92134014010085
# *** accuracy is 0.658578856152513 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:22:22
# finished network propagation: 23:22:23
# finished calculating P_grad using pool: 23:22:53
# finished calculating J and J_grad: 23:22:54
# *** 62 iteration: J is 210.73831061684342 cost_val is 107.8788758438733
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:22:54
# finished network propagation: 23:22:55
# finished calculating P_grad using pool: 23:23:25
# finished calculating J and J_grad: 23:23:26
# *** 63 iteration: J is 210.31383256349918 cost_val is 107.63923034433824
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:23:27
# finished network propagation: 23:23:27
# finished calculating P_grad using pool: 23:23:57
# finished calculating J and J_grad: 23:23:59
# *** 64 iteration: J is 211.25283980777135 cost_val is 107.9817089091391
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:23:59
# finished network propagation: 23:23:59
# finished calculating P_grad using pool: 23:24:30
# finished calculating J and J_grad: 23:24:31
# *** 65 iteration: J is 210.5120317639749 cost_val is 106.45343937797286
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:24:31
# finished network propagation: 23:24:32
# finished calculating P_grad using pool: 23:25:02
# finished calculating J and J_grad: 23:25:04
# *** 66 iteration: J is 210.73637664482996 cost_val is 106.70604668063956
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:25:04
# finished network propagation: 23:25:05
# finished calculating P_grad using pool: 23:25:35
# finished calculating J and J_grad: 23:25:37
# *** 67 iteration: J is 210.46061539777892 cost_val is 107.15439684275893
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:25:37
# finished network propagation: 23:25:37
# finished calculating P_grad using pool: 23:26:08
# finished calculating J and J_grad: 23:26:09
# *** 68 iteration: J is 212.9754993675018 cost_val is 107.02867878904863
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:26:09
# finished network propagation: 23:26:10
# finished calculating P_grad using pool: 23:26:40
# finished calculating J and J_grad: 23:26:42
# *** 69 iteration: J is 212.48152972387854 cost_val is 108.57551745964224
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:26:42
# finished network propagation: 23:26:43
# finished calculating P_grad using pool: 23:27:13
# finished calculating J and J_grad: 23:27:15
# *** 70 iteration: J is 213.52524737670532 cost_val is 106.50611282860444
# *** accuracy is 0.6533795493934142 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:27:15
# finished network propagation: 23:27:15
# finished calculating P_grad using pool: 23:27:46
# finished calculating J and J_grad: 23:27:47
# *** 71 iteration: J is 212.0980536319023 cost_val is 107.11480991511597
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:27:47
# finished network propagation: 23:27:48
# finished calculating P_grad using pool: 23:28:18
# finished calculating J and J_grad: 23:28:20
# *** 72 iteration: J is 213.87777143989527 cost_val is 107.97341941645054
# *** accuracy is 0.6568457538994801 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:28:20
# finished network propagation: 23:28:20
# finished calculating P_grad using pool: 23:28:51
# finished calculating J and J_grad: 23:28:52
# *** 73 iteration: J is 214.29436529214792 cost_val is 107.47126161615016
# *** accuracy is 0.6533795493934142 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:28:52
# finished network propagation: 23:28:53
# finished calculating P_grad using pool: 23:29:24
# finished calculating J and J_grad: 23:29:25
# *** 74 iteration: J is 211.25491590357413 cost_val is 106.47528658097448
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6328671328671329
#
#
# finished calculating strength_grad: 23:29:25
# finished network propagation: 23:29:26
# finished calculating P_grad using pool: 23:29:56
# finished calculating J and J_grad: 23:29:58
# *** 75 iteration: J is 213.81393189701893 cost_val is 106.05688800004489
# *** accuracy is 0.6516464471403813 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:29:58
# finished network propagation: 23:29:59
# finished calculating P_grad using pool: 23:30:29
# finished calculating J and J_grad: 23:30:31
# *** 76 iteration: J is 212.58650126064086 cost_val is 106.0908832498837
# *** accuracy is 0.6551126516464472 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:30:31
# finished network propagation: 23:30:32
# finished calculating P_grad using pool: 23:31:02
# finished calculating J and J_grad: 23:31:03
# *** 77 iteration: J is 209.9672996922792 cost_val is 106.6214357989305
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:31:03
# finished network propagation: 23:31:04
# finished calculating P_grad using pool: 23:31:34
# finished calculating J and J_grad: 23:31:36
# *** 78 iteration: J is 211.20027611016488 cost_val is 106.69919250427544
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:31:36
# finished network propagation: 23:31:37
# finished calculating P_grad using pool: 23:32:07
# finished calculating J and J_grad: 23:32:08
# *** 79 iteration: J is 210.84852428948875 cost_val is 106.95118117243393
# *** accuracy is 0.6655112651646448 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:32:08
# finished network propagation: 23:32:09
# finished calculating P_grad using pool: 23:32:39
# finished calculating J and J_grad: 23:32:41
# *** 80 iteration: J is 209.15861542160042 cost_val is 106.32461504100038
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:32:41
# finished network propagation: 23:32:41
# finished calculating P_grad using pool: 23:33:12
# finished calculating J and J_grad: 23:33:14
# *** 81 iteration: J is 210.05477221391 cost_val is 105.88626404955514
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:33:14
# finished network propagation: 23:33:14
# finished calculating P_grad using pool: 23:33:45
# finished calculating J and J_grad: 23:33:46
# *** 82 iteration: J is 209.79130416487794 cost_val is 106.41743796592107
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:33:47
# finished network propagation: 23:33:47
# finished calculating P_grad using pool: 23:34:17
# finished calculating J and J_grad: 23:34:19
# *** 83 iteration: J is 208.76567805953098 cost_val is 106.76322310122467
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6328671328671329
#
#
# finished calculating strength_grad: 23:34:19
# finished network propagation: 23:34:20
# finished calculating P_grad using pool: 23:34:50
# finished calculating J and J_grad: 23:34:52
# *** 84 iteration: J is 212.17515220476565 cost_val is 108.15197252706494
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 23:34:52
# finished network propagation: 23:34:52
# finished calculating P_grad using pool: 23:35:23
# finished calculating J and J_grad: 23:35:24
# *** 85 iteration: J is 215.00563690095103 cost_val is 107.46999052244993
# *** accuracy is 0.6533795493934142 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:35:24
# finished network propagation: 23:35:25
# finished calculating P_grad using pool: 23:35:55
# finished calculating J and J_grad: 23:35:56
# *** 86 iteration: J is 211.49377865164584 cost_val is 108.34764344289049
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:35:56
# finished network propagation: 23:35:57
# finished calculating P_grad using pool: 23:36:27
# finished calculating J and J_grad: 23:36:29
# *** 87 iteration: J is 211.64331629579283 cost_val is 108.69960302704294
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:36:29
# finished network propagation: 23:36:29
# finished calculating P_grad using pool: 23:37:00
# finished calculating J and J_grad: 23:37:02
# *** 88 iteration: J is 213.1762711632271 cost_val is 108.34069235311928
# *** accuracy is 0.658578856152513 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:37:02
# finished network propagation: 23:37:02
# finished calculating P_grad using pool: 23:37:34
# finished calculating J and J_grad: 23:37:35
# *** 89 iteration: J is 211.278510985284 cost_val is 107.70875065966051
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:37:35
# finished network propagation: 23:37:36
# finished calculating P_grad using pool: 23:38:07
# finished calculating J and J_grad: 23:38:08
# *** 90 iteration: J is 211.48371420644108 cost_val is 107.61186573336114
# *** accuracy is 0.658578856152513 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:38:08
# finished network propagation: 23:38:09
# finished calculating P_grad using pool: 23:38:39
# finished calculating J and J_grad: 23:38:41
# *** 91 iteration: J is 211.37061090217603 cost_val is 108.30234041983945
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:38:41
# finished network propagation: 23:38:42
# finished calculating P_grad using pool: 23:39:12
# finished calculating J and J_grad: 23:39:13
# *** 92 iteration: J is 209.6256291796903 cost_val is 108.01243395554896
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:39:14
# finished network propagation: 23:39:14
# finished calculating P_grad using pool: 23:39:44
# finished calculating J and J_grad: 23:39:46
# *** 93 iteration: J is 209.10745579733998 cost_val is 108.18883893805095
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:39:46
# finished network propagation: 23:39:47
# finished calculating P_grad using pool: 23:40:17
# finished calculating J and J_grad: 23:40:18
# *** 94 iteration: J is 211.13923793212686 cost_val is 108.03348088023208
# *** accuracy is 0.6603119584055459 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:40:18
# finished network propagation: 23:40:19
# finished calculating P_grad using pool: 23:40:49
# finished calculating J and J_grad: 23:40:51
# *** 95 iteration: J is 210.56397677504935 cost_val is 108.1392554033093
# *** accuracy is 0.6620450606585788 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:40:51
# finished network propagation: 23:40:51
# finished calculating P_grad using pool: 23:41:22
# finished calculating J and J_grad: 23:41:23
# *** 96 iteration: J is 211.08666017385036 cost_val is 108.16108937590981
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:41:23
# finished network propagation: 23:41:24
# finished calculating P_grad using pool: 23:41:54
# finished calculating J and J_grad: 23:41:55
# *** 97 iteration: J is 210.57328782624887 cost_val is 108.30512036203059
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:41:55
# finished network propagation: 23:41:56
# finished calculating P_grad using pool: 23:42:25
# finished calculating J and J_grad: 23:42:27
# *** 98 iteration: J is 209.05332530376583 cost_val is 108.36112237942561
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:42:27
# finished network propagation: 23:42:28
# finished calculating P_grad using pool: 23:42:57
# finished calculating J and J_grad: 23:42:58
# *** 99 iteration: J is 210.72489820469036 cost_val is 107.81201324843641
# *** accuracy is 0.6655112651646448 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:42:59
# finished network propagation: 23:42:59
# finished calculating P_grad using pool: 23:43:28
# finished calculating J and J_grad: 23:43:30
# *** 100 iteration: J is 210.15275818525353 cost_val is 107.73751978293093
# *** accuracy is 0.6637781629116117 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:43:30
# finished network propagation: 23:43:30
# finished calculating P_grad using pool: 23:43:59
# finished calculating J and J_grad: 23:44:01
# *** 101 iteration: J is 209.41105422774564 cost_val is 108.37365215279925
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:44:01
# finished network propagation: 23:44:02
# finished calculating P_grad using pool: 23:44:30
# finished calculating J and J_grad: 23:44:32
# *** 102 iteration: J is 209.47797801890485 cost_val is 109.16202304611072
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:44:32
# finished network propagation: 23:44:32
# finished calculating P_grad using pool: 23:45:01
# finished calculating J and J_grad: 23:45:03
# *** 103 iteration: J is 209.08044162609843 cost_val is 108.60826603669346
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:45:03
# finished network propagation: 23:45:04
# finished calculating P_grad using pool: 23:45:33
# finished calculating J and J_grad: 23:45:34
# *** 104 iteration: J is 209.1538387506675 cost_val is 108.30054242568274
# *** accuracy is 0.6655112651646448 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:45:35
# finished network propagation: 23:45:35
# finished calculating P_grad using pool: 23:46:05
# finished calculating J and J_grad: 23:46:06
# *** 105 iteration: J is 207.97257754239357 cost_val is 108.54609503850504
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:46:06
# finished network propagation: 23:46:07
# finished calculating P_grad using pool: 23:46:37
# finished calculating J and J_grad: 23:46:38
# *** 106 iteration: J is 208.7258300663114 cost_val is 108.76017860431215
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:46:39
# finished network propagation: 23:46:39
# finished calculating P_grad using pool: 23:47:09
# finished calculating J and J_grad: 23:47:10
# *** 107 iteration: J is 208.14202175095667 cost_val is 109.15993584869767
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:47:11
# finished network propagation: 23:47:11
# finished calculating P_grad using pool: 23:47:42
# finished calculating J and J_grad: 23:47:44
# *** 108 iteration: J is 207.91770910092953 cost_val is 109.68200185246161
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:47:44
# finished network propagation: 23:47:44
# finished calculating P_grad using pool: 23:48:14
# finished calculating J and J_grad: 23:48:16
# *** 109 iteration: J is 207.78874158593771 cost_val is 109.61958379476404
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:48:16
# finished network propagation: 23:48:17
# finished calculating P_grad using pool: 23:48:47
# finished calculating J and J_grad: 23:48:48
# *** 110 iteration: J is 208.12828095287333 cost_val is 109.40330069211022
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:48:48
# finished network propagation: 23:48:49
# finished calculating P_grad using pool: 23:49:19
# finished calculating J and J_grad: 23:49:21
# *** 111 iteration: J is 207.6049371232934 cost_val is 109.58702712017528
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:49:21
# finished network propagation: 23:49:21
# finished calculating P_grad using pool: 23:49:51
# finished calculating J and J_grad: 23:49:53
# *** 112 iteration: J is 207.5204890995315 cost_val is 109.57542949080421
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6293706293706294
#
#
# finished calculating strength_grad: 23:49:53
# finished network propagation: 23:49:53
# finished calculating P_grad using pool: 23:50:24
# finished calculating J and J_grad: 23:50:25
# *** 113 iteration: J is 207.35772825422563 cost_val is 109.14777346858986
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:50:25
# finished network propagation: 23:50:26
# finished calculating P_grad using pool: 23:50:56
# finished calculating J and J_grad: 23:50:57
# *** 114 iteration: J is 207.7301207608182 cost_val is 108.57014639858728
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:50:57
# finished network propagation: 23:50:58
# finished calculating P_grad using pool: 23:51:28
# finished calculating J and J_grad: 23:51:29
# *** 115 iteration: J is 206.98985486181036 cost_val is 108.96269072567081
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:51:30
# finished network propagation: 23:51:30
# finished calculating P_grad using pool: 23:52:00
# finished calculating J and J_grad: 23:52:01
# *** 116 iteration: J is 207.56190243271007 cost_val is 109.97031053473691
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:52:02
# finished network propagation: 23:52:02
# finished calculating P_grad using pool: 23:52:32
# finished calculating J and J_grad: 23:52:33
# *** 117 iteration: J is 207.40595953134596 cost_val is 109.39470645109175
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:52:34
# finished network propagation: 23:52:34
# finished calculating P_grad using pool: 23:53:04
# finished calculating J and J_grad: 23:53:06
# *** 118 iteration: J is 207.33037360010567 cost_val is 108.4723163113137
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:53:06
# finished network propagation: 23:53:07
# finished calculating P_grad using pool: 23:53:37
# finished calculating J and J_grad: 23:53:38
# *** 119 iteration: J is 206.76079906571886 cost_val is 108.76062452774767
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:53:39
# finished network propagation: 23:53:39
# finished calculating P_grad using pool: 23:54:09
# finished calculating J and J_grad: 23:54:11
# *** 120 iteration: J is 206.90954628817786 cost_val is 109.24469620836275
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:54:11
# finished network propagation: 23:54:11
# finished calculating P_grad using pool: 23:54:41
# finished calculating J and J_grad: 23:54:43
# *** 121 iteration: J is 206.57382903625614 cost_val is 109.0768628043391
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:54:43
# finished network propagation: 23:54:44
# finished calculating P_grad using pool: 23:55:14
# finished calculating J and J_grad: 23:55:15
# *** 122 iteration: J is 206.6078771482814 cost_val is 108.83156551330154
# *** accuracy is 0.6672443674176777 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:55:15
# finished network propagation: 23:55:16
# finished calculating P_grad using pool: 23:55:46
# finished calculating J and J_grad: 23:55:48
# *** 123 iteration: J is 206.59252034872492 cost_val is 108.99631054889925
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6258741258741258
#
#
# finished calculating strength_grad: 23:55:48
# finished network propagation: 23:55:48
# finished calculating P_grad using pool: 23:56:19
# finished calculating J and J_grad: 23:56:20
# *** 124 iteration: J is 206.57477457661676 cost_val is 109.76037259352631
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:56:21
# finished network propagation: 23:56:21
# finished calculating P_grad using pool: 23:56:51
# finished calculating J and J_grad: 23:56:53
# *** 125 iteration: J is 206.05099613305006 cost_val is 109.48637576324802
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6188811188811189
#
#
# finished calculating strength_grad: 23:56:53
# finished network propagation: 23:56:53
# finished calculating P_grad using pool: 23:57:23
# finished calculating J and J_grad: 23:57:25
# *** 126 iteration: J is 206.7569703080056 cost_val is 109.10638145880785
# *** accuracy is 0.6741767764298093 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:57:25
# finished network propagation: 23:57:26
# finished calculating P_grad using pool: 23:57:56
# finished calculating J and J_grad: 23:57:57
# *** 127 iteration: J is 206.41461967480282 cost_val is 109.85381344093808
# *** accuracy is 0.6689774696707106 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 23:57:57
# finished network propagation: 23:57:58
# finished calculating P_grad using pool: 23:58:28
# finished calculating J and J_grad: 23:58:30
# *** 128 iteration: J is 206.57185641435495 cost_val is 110.63748963111787
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 23:58:30
# finished network propagation: 23:58:30
# finished calculating P_grad using pool: 23:59:00
# finished calculating J and J_grad: 23:59:02
# *** 129 iteration: J is 205.75996653858024 cost_val is 109.82172761201969
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 23:59:02
# finished network propagation: 23:59:03
# finished calculating P_grad using pool: 23:59:33
# finished calculating J and J_grad: 23:59:34
# *** 130 iteration: J is 206.24980918446084 cost_val is 108.94995022206032
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 23:59:35
# finished network propagation: 23:59:35
# finished calculating P_grad using pool: 00:00:06
# finished calculating J and J_grad: 00:00:07
# *** 131 iteration: J is 205.38309689561706 cost_val is 109.89044190109435
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 00:00:07
# finished network propagation: 00:00:08
# finished calculating P_grad using pool: 00:00:39
# finished calculating J and J_grad: 00:00:40
# *** 132 iteration: J is 205.41102575895385 cost_val is 110.1527275520348
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:00:41
# finished network propagation: 00:00:41
# finished calculating P_grad using pool: 00:01:11
# finished calculating J and J_grad: 00:01:13
# *** 133 iteration: J is 205.01797502760112 cost_val is 109.53985146065187
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:01:13
# finished network propagation: 00:01:13
# finished calculating P_grad using pool: 00:01:44
# finished calculating J and J_grad: 00:01:45
# *** 134 iteration: J is 205.97193296080826 cost_val is 109.49714177975666
# *** accuracy is 0.6724436741767764 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 00:01:45
# finished network propagation: 00:01:46
# finished calculating P_grad using pool: 00:02:16
# finished calculating J and J_grad: 00:02:18
# *** 135 iteration: J is 205.0337357353593 cost_val is 109.75750769903905
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 00:02:18
# finished network propagation: 00:02:18
# finished calculating P_grad using pool: 00:02:49
# finished calculating J and J_grad: 00:02:50
# *** 136 iteration: J is 204.97153465003794 cost_val is 109.78274805525426
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:02:50
# finished network propagation: 00:02:51
# finished calculating P_grad using pool: 00:03:21
# finished calculating J and J_grad: 00:03:23
# *** 137 iteration: J is 204.99834110634112 cost_val is 109.98247053822833
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 00:03:23
# finished network propagation: 00:03:23
# finished calculating P_grad using pool: 00:03:54
# finished calculating J and J_grad: 00:03:55
# *** 138 iteration: J is 204.81021551672987 cost_val is 110.27070162400337
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:03:55
# finished network propagation: 00:03:56
# finished calculating P_grad using pool: 00:04:26
# finished calculating J and J_grad: 00:04:27
# *** 139 iteration: J is 204.34466049481728 cost_val is 110.33394278423094
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 00:04:28
# finished network propagation: 00:04:28
# finished calculating P_grad using pool: 00:04:58
# finished calculating J and J_grad: 00:05:00
# *** 140 iteration: J is 204.95780765055957 cost_val is 109.92074328088782
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:05:00
# finished network propagation: 00:05:00
# finished calculating P_grad using pool: 00:05:31
# finished calculating J and J_grad: 00:05:32
# *** 141 iteration: J is 204.81061724075394 cost_val is 110.23069925380075
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:05:32
# finished network propagation: 00:05:33
# finished calculating P_grad using pool: 00:06:03
# finished calculating J and J_grad: 00:06:04
# *** 142 iteration: J is 205.83068888947852 cost_val is 111.7168099292053
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 00:06:05
# finished network propagation: 00:06:05
# finished calculating P_grad using pool: 00:06:35
# finished calculating J and J_grad: 00:06:37
# *** 143 iteration: J is 205.07799107097324 cost_val is 110.66678017929277
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6153846153846154
#
#
# finished calculating strength_grad: 00:06:37
# finished network propagation: 00:06:38
# finished calculating P_grad using pool: 00:07:08
# finished calculating J and J_grad: 00:07:09
# *** 144 iteration: J is 205.01844299749604 cost_val is 109.77603241916974
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 00:07:10
# finished network propagation: 00:07:10
# finished calculating P_grad using pool: 00:07:40
# finished calculating J and J_grad: 00:07:42
# *** 145 iteration: J is 205.26576727498832 cost_val is 110.3038913068086
# *** accuracy is 0.6707105719237435 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 00:07:42
# finished network propagation: 00:07:43
# finished calculating P_grad using pool: 00:08:13
# finished calculating J and J_grad: 00:08:15
# *** 146 iteration: J is 204.53387809481495 cost_val is 110.48579648581945
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 00:08:15
# finished network propagation: 00:08:15
# finished calculating P_grad using pool: 00:08:45
# finished calculating J and J_grad: 00:08:47
# *** 147 iteration: J is 204.68431322214568 cost_val is 110.0307187163563
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 00:08:47
# finished network propagation: 00:08:48
# finished calculating P_grad using pool: 00:09:18
# finished calculating J and J_grad: 00:09:20
# *** 148 iteration: J is 205.4400941202951 cost_val is 110.28597293810853
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 00:09:20
# ...
# finished calculating J and J_grad: 02:53:49
# *** 448 iteration: J is 202.92809265537085 cost_val is 114.51283293910905
# *** accuracy is 0.6793760831889082 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 02:53:49
# finished network propagation: 02:53:50
# finished calculating P_grad using pool: 02:54:20
# finished calculating J and J_grad: 02:54:22
# *** 449 iteration: J is 205.1658276387468 cost_val is 114.50784988710218
# *** accuracy is 0.6759098786828422 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 02:54:22
# finished network propagation: 02:54:23
# finished calculating P_grad using pool: 02:54:53
# finished calculating J and J_grad: 02:54:55
# *** 450 iteration: J is 203.51532044020425 cost_val is 114.59644683426846
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 02:54:55
# finished network propagation: 02:54:55
# finished calculating P_grad using pool: 02:55:26
# finished calculating J and J_grad: 02:55:27
# *** 451 iteration: J is 203.85723056777786 cost_val is 113.49306439915622
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 02:55:28
# finished network propagation: 02:55:28
# finished calculating P_grad using pool: 02:55:59
# finished calculating J and J_grad: 02:56:00
# *** 452 iteration: J is 203.72513998196663 cost_val is 109.79293702163363
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 02:56:01
# finished network propagation: 02:56:01
# finished calculating P_grad using pool: 02:56:32
# finished calculating J and J_grad: 02:56:33
# *** 453 iteration: J is 204.55340509479385 cost_val is 111.97735697938228
# *** accuracy is 0.6741767764298093 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 02:56:33
# finished network propagation: 02:56:34
# finished calculating P_grad using pool: 02:57:04
# finished calculating J and J_grad: 02:57:06
# *** 454 iteration: J is 202.51650592236166 cost_val is 113.99916570506011
# *** accuracy is 0.682842287694974 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 02:57:06
# finished network propagation: 02:57:07
# finished calculating P_grad using pool: 02:57:38
# finished calculating J and J_grad: 02:57:39
# *** 455 iteration: J is 204.08230655147025 cost_val is 115.63596645015848
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 02:57:39
# finished network propagation: 02:57:40
# finished calculating P_grad using pool: 02:58:11
# finished calculating J and J_grad: 02:58:12
# *** 456 iteration: J is 203.83855340826426 cost_val is 114.87647051447242
# *** accuracy is 0.6776429809358753 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 02:58:12
# finished network propagation: 02:58:13
# finished calculating P_grad using pool: 02:58:44
# finished calculating J and J_grad: 02:58:46
# *** 457 iteration: J is 203.9823485879827 cost_val is 114.48767183641652
# *** accuracy is 0.6776429809358753 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 02:58:46
# finished network propagation: 02:58:46
# finished calculating P_grad using pool: 02:59:18
# finished calculating J and J_grad: 02:59:19
# *** 458 iteration: J is 204.00247390264383 cost_val is 115.32018945413974
# *** accuracy is 0.6759098786828422 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 02:59:19
# finished network propagation: 02:59:20
# finished calculating P_grad using pool: 02:59:50
# finished calculating J and J_grad: 02:59:52
# *** 459 iteration: J is 201.53421922759284 cost_val is 115.66498166750948
# *** accuracy is 0.682842287694974 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 02:59:52
# finished network propagation: 02:59:53
# finished calculating P_grad using pool: 03:00:23
# finished calculating J and J_grad: 03:00:25
# *** 460 iteration: J is 202.8662601327147 cost_val is 114.86932772910832
# *** accuracy is 0.6776429809358753 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:00:25
# finished network propagation: 03:00:26
# finished calculating P_grad using pool: 03:00:56
# finished calculating J and J_grad: 03:00:58
# *** 461 iteration: J is 201.53584257244654 cost_val is 114.44026076037774
# *** accuracy is 0.682842287694974 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:00:58
# finished network propagation: 03:00:59
# finished calculating P_grad using pool: 03:01:29
# finished calculating J and J_grad: 03:01:31
# *** 462 iteration: J is 202.9542191323426 cost_val is 113.62525402269846
# *** accuracy is 0.6793760831889082 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 03:01:31
# finished network propagation: 03:01:32
# finished calculating P_grad using pool: 03:02:02
# finished calculating J and J_grad: 03:02:04
# *** 463 iteration: J is 203.3182773551031 cost_val is 113.66664930297401
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:02:04
# finished network propagation: 03:02:04
# finished calculating P_grad using pool: 03:02:36
# finished calculating J and J_grad: 03:02:38
# *** 464 iteration: J is 203.74636731693838 cost_val is 114.47557416341999
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:02:38
# finished network propagation: 03:02:38
# finished calculating P_grad using pool: 03:03:10
# finished calculating J and J_grad: 03:03:11
# *** 465 iteration: J is 203.38678631487468 cost_val is 115.71786070513147
# *** accuracy is 0.6776429809358753 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:03:11
# finished network propagation: 03:03:12
# finished calculating P_grad using pool: 03:03:43
# finished calculating J and J_grad: 03:03:44
# *** 466 iteration: J is 202.81945388348896 cost_val is 115.86210674826208
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:03:45
# finished network propagation: 03:03:45
# finished calculating P_grad using pool: 03:04:16
# finished calculating J and J_grad: 03:04:18
# *** 467 iteration: J is 202.5490874462609 cost_val is 115.31204108683566
# *** accuracy is 0.682842287694974 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:04:18
# finished network propagation: 03:04:18
# finished calculating P_grad using pool: 03:04:49
# finished calculating J and J_grad: 03:04:51
# *** 468 iteration: J is 201.63783437646842 cost_val is 113.8306058568263
# *** accuracy is 0.6811091854419411 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 03:04:51
# finished network propagation: 03:04:52
# finished calculating P_grad using pool: 03:05:22
# finished calculating J and J_grad: 03:05:24
# *** 469 iteration: J is 203.00406755613554 cost_val is 112.39330772804585
# *** accuracy is 0.6793760831889082 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 03:05:24
# finished network propagation: 03:05:25
# finished calculating P_grad using pool: 03:05:55
# finished calculating J and J_grad: 03:05:57
# *** 470 iteration: J is 202.17510454681013 cost_val is 114.19751006648876
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:05:57
# finished network propagation: 03:05:57
# finished calculating P_grad using pool: 03:06:28
# finished calculating J and J_grad: 03:06:30
# *** 471 iteration: J is 201.98563266725012 cost_val is 116.52908350557131
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:06:30
# finished network propagation: 03:06:30
# finished calculating P_grad using pool: 03:07:01
# finished calculating J and J_grad: 03:07:03
# *** 472 iteration: J is 203.5361445217172 cost_val is 117.11795765498452
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:07:03
# finished network propagation: 03:07:03
# finished calculating P_grad using pool: 03:07:34
# finished calculating J and J_grad: 03:07:36
# *** 473 iteration: J is 203.48237769062374 cost_val is 115.37941458396465
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:07:36
# finished network propagation: 03:07:36
# finished calculating P_grad using pool: 03:08:07
# finished calculating J and J_grad: 03:08:09
# *** 474 iteration: J is 203.3042941318031 cost_val is 114.28031165218621
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:08:09
# finished network propagation: 03:08:09
# finished calculating P_grad using pool: 03:08:40
# finished calculating J and J_grad: 03:08:42
# *** 475 iteration: J is 203.15954322855058 cost_val is 113.97010408745027
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:08:42
# finished network propagation: 03:08:42
# finished calculating P_grad using pool: 03:09:13
# finished calculating J and J_grad: 03:09:15
# *** 476 iteration: J is 203.27327679213082 cost_val is 113.1987193440999
# *** accuracy is 0.6793760831889082 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 03:09:15
# finished network propagation: 03:09:15
# finished calculating P_grad using pool: 03:09:46
# finished calculating J and J_grad: 03:09:48
# *** 477 iteration: J is 202.9895705483484 cost_val is 112.40731899162215
# *** accuracy is 0.6793760831889082 accuracy_val is 0.6118881118881119
#
#
# finished calculating strength_grad: 03:09:48
# finished network propagation: 03:09:49
# finished calculating P_grad using pool: 03:10:19
# finished calculating J and J_grad: 03:10:21
# *** 478 iteration: J is 202.35142795442187 cost_val is 113.56275327796666
# *** accuracy is 0.6811091854419411 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:10:21
# finished network propagation: 03:10:22
# finished calculating P_grad using pool: 03:10:52
# finished calculating J and J_grad: 03:10:54
# *** 479 iteration: J is 202.5253023575203 cost_val is 114.90697209120769
# *** accuracy is 0.6811091854419411 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:10:54
# finished network propagation: 03:10:54
# finished calculating P_grad using pool: 03:11:25
# finished calculating J and J_grad: 03:11:27
# *** 480 iteration: J is 202.11096392188725 cost_val is 116.178670440455
# *** accuracy is 0.682842287694974 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:11:27
# finished network propagation: 03:11:28
# finished calculating P_grad using pool: 03:11:59
# finished calculating J and J_grad: 03:12:00
# *** 481 iteration: J is 202.06240741367913 cost_val is 116.2470478937846
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:12:01
# finished network propagation: 03:12:01
# finished calculating P_grad using pool: 03:12:32
# finished calculating J and J_grad: 03:12:34
# *** 482 iteration: J is 203.42493716994798 cost_val is 116.14819972795905
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:12:34
# finished network propagation: 03:12:34
# finished calculating P_grad using pool: 03:13:06
# finished calculating J and J_grad: 03:13:07
# *** 483 iteration: J is 202.1880006955897 cost_val is 115.3499123739392
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:13:07
# finished network propagation: 03:13:08
# finished calculating P_grad using pool: 03:13:39
# finished calculating J and J_grad: 03:13:41
# *** 484 iteration: J is 204.6186907170607 cost_val is 114.3791494577187
# *** accuracy is 0.6776429809358753 accuracy_val is 0.6048951048951049
#
#
# finished calculating strength_grad: 03:13:41
# finished network propagation: 03:13:41
# finished calculating P_grad using pool: 03:14:12
# finished calculating J and J_grad: 03:14:14
# *** 485 iteration: J is 202.7215969129806 cost_val is 114.91564379388068
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:14:14
# finished network propagation: 03:14:15
# finished calculating P_grad using pool: 03:14:45
# finished calculating J and J_grad: 03:14:47
# *** 486 iteration: J is 202.9146854199347 cost_val is 115.15340186493282
# *** accuracy is 0.6776429809358753 accuracy_val is 0.5944055944055944
#
#
# finished calculating strength_grad: 03:14:47
# finished network propagation: 03:14:47
# finished calculating P_grad using pool: 03:15:19
# finished calculating J and J_grad: 03:15:20
# *** 487 iteration: J is 203.19013559265102 cost_val is 116.34396275019981
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:15:20
# finished network propagation: 03:15:21
# finished calculating P_grad using pool: 03:15:51
# finished calculating J and J_grad: 03:15:53
# *** 488 iteration: J is 202.880229458209 cost_val is 115.67791309474136
# *** accuracy is 0.6793760831889082 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:15:53
# finished network propagation: 03:15:54
# finished calculating P_grad using pool: 03:16:25
# finished calculating J and J_grad: 03:16:26
# *** 489 iteration: J is 202.79964555762305 cost_val is 114.22575839510566
# *** accuracy is 0.6811091854419411 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:16:26
# finished network propagation: 03:16:27
# finished calculating P_grad using pool: 03:16:58
# finished calculating J and J_grad: 03:16:59
# *** 490 iteration: J is 202.33837704982437 cost_val is 111.85830184009446
# *** accuracy is 0.6759098786828422 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 03:16:59
# finished network propagation: 03:17:00
# finished calculating P_grad using pool: 03:17:31
# finished calculating J and J_grad: 03:17:32
# *** 491 iteration: J is 203.83501609543032 cost_val is 110.33687111605444
# *** accuracy is 0.6741767764298093 accuracy_val is 0.6223776223776224
#
#
# finished calculating strength_grad: 03:17:32
# finished network propagation: 03:17:33
# finished calculating P_grad using pool: 03:18:04
# finished calculating J and J_grad: 03:18:05
# *** 492 iteration: J is 201.3916032460954 cost_val is 113.19388751473218
# *** accuracy is 0.6811091854419411 accuracy_val is 0.6083916083916084
#
#
# finished calculating strength_grad: 03:18:05
# finished network propagation: 03:18:06
# finished calculating P_grad using pool: 03:18:37
# finished calculating J and J_grad: 03:18:38
# *** 493 iteration: J is 202.19708146169285 cost_val is 114.74724812156549
# *** accuracy is 0.682842287694974 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:18:39
# finished network propagation: 03:18:39
# finished calculating P_grad using pool: 03:19:10
# finished calculating J and J_grad: 03:19:12
# *** 494 iteration: J is 201.7316368705246 cost_val is 115.51996930069413
# *** accuracy is 0.682842287694974 accuracy_val is 0.5909090909090909
#
#
# finished calculating strength_grad: 03:19:12
# finished network propagation: 03:19:12
# finished calculating P_grad using pool: 03:19:43
# finished calculating J and J_grad: 03:19:45
# *** 495 iteration: J is 201.5990500924898 cost_val is 115.14958089811202
# *** accuracy is 0.6811091854419411 accuracy_val is 0.5979020979020979
#
#
# finished calculating strength_grad: 03:19:45
# finished network propagation: 03:19:46
# finished calculating P_grad using pool: 03:20:17
# finished calculating J and J_grad: 03:20:18
# *** 496 iteration: J is 201.48110952686932 cost_val is 115.06978131945104
# *** accuracy is 0.6845753899480069 accuracy_val is 0.6013986013986014
#
#
# finished calculating strength_grad: 03:20:18
# finished network propagation: 03:20:19
# finished calculating P_grad using pool: 03:20:50
# finished calculating J and J_grad: 03:20:51
# *** 497 iteration: J is 201.47965024295746 cost_val is 115.52665802062923
# *** accuracy is 0.682842287694974 accuracy_val is 0.5979020979020979

# %% [markdown]
# # After convergence

# %%
# Output learned feature weights to a file
SRW_obj.w_map.to_csv('data/BRCA_edge_feature_weights_2.txt', sep='\t')

# %%
# Generate SRW_obj.Q_fin_df, the final transition matrix, 
# and SRW_obj.P_fin_df, the final propagated mutation profiles
SRW_obj.generate_Q_and_P_fin()

# %%
# Save the object
with open('data/SRW_obj_2', 'wb') as output:
    pickle.dump(SRW_obj, output, pickle.HIGHEST_PROTOCOL)
